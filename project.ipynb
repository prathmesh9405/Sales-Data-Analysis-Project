# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Realistic_Sales_Data_1000_Records.csv")

# %%
df.head()
# Out:
#    Order_ID  Order_Date Customer_ID       Customer_Name  Gender  Age  \
# 0     10001  2025-04-25    CUST1016         Aarav Reddy    Male   23
# 1     10002  2026-06-02    CUST1004        Meera Sharma  Female   28
# 2     10003  2025-12-15    CUST1236  Siddharth Kulkarni    Male   52
# 3     10004  2025-03-22    CUST1149          Isha Gupta  Female   23
# 4     10005  2026-01-25    CUST1037     Siddharth Verma    Male   56
#
#           City      State Region Product_ID  ...     Category   Sub_Category  \
# 0       Jaipur  Rajasthan  North    PROD114  ...  Electronics    Accessories
# 1    Hyderabad  Telangana  South    PROD145  ...  Electronics    Accessories
# 2        Delhi      Delhi  North    PROD108  ...       Sports        Fitness
# 3  Bhubaneswar     Odisha   East    PROD115  ...      Fashion          Women
# 4  Bhubaneswar     Odisha   East    PROD141  ...       Beauty  Personal Care
#
#   Unit_Price  Quantity  Discount_Percent  Discount_Amount    Sales   Profit  \
# 0    2814.83         1                12           337.78  2477.05   342.68
# 1    2723.44         2                12           653.63  4793.25   466.10
# 2    1645.18         1                10           164.52  1480.66   253.76
# 3    1531.76         3                 0             0.00  4595.28  1905.40
# 4    1736.51         1                10           173.65  1562.86   517.66
#
#    Payment_Method Order_Status
# 0     Credit Card    Delivered
# 1     Net Banking    Delivered
# 2     Net Banking    Delivered
# 3             UPI    Delivered
# 4     Credit Card    Delivered
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1000 non-null   int64
#  1   Order_Date        1000 non-null   object
#  2   Customer_ID       1000 non-null   object
#  3   Customer_Name     1000 non-null   object
#  4   Gender            1000 non-null   object
#  5   Age               1000 non-null   int64
#  6   City              1000 non-null   object
#  7   State             1000 non-null   object
#  8   Region            1000 non-null   object
#  9   Product_ID        1000 non-null   object
#  10  Product_Name      1000 non-null   object
#  11  Category          1000 non-null   object
#  12  Sub_Category      1000 non-null   object
#  13  Unit_Price        1000 non-null   float64
#  14  Quantity          1000 non-null   int64
#  15  Discount_Percent  1000 non-null   int64
#  16  Discount_Amount   1000 non-null   float64
#  17  Sales             1000 non-null   float64
#  18  Profit            1000 non-null   float64
#  19  Payment_Method    1000 non-null   object
#  20  Order_Status      1000 non-null   object
# dtypes: float64(4), int64(4), object(13)
# memory usage: 164.2+ KB

# %%
df.describe()
# Out:
#            Order_ID          Age    Unit_Price     Quantity  Discount_Percent  \
# count   1000.000000  1000.000000   1000.000000  1000.000000       1000.000000
# mean   10500.500000    40.931000  11045.792940     1.931000          9.779000
# std      288.819436    14.142569  19339.827364     1.037938          5.909745
# min    10001.000000    18.000000    405.190000     1.000000          0.000000
# 25%    10250.750000    28.000000   1715.492500     1.000000          5.000000
# 50%    10500.500000    40.000000   3407.120000     2.000000         10.000000
# 75%    10750.250000    53.000000   8344.132500     2.000000         15.000000
# max    11000.000000    65.000000  94922.720000     5.000000         22.000000
#
#        Discount_Amount          Sales        Profit
# count      1000.000000    1000.000000   1000.000000
# mean       1843.136670   20513.624460   2624.932900
# std        4604.104613   45258.885093   6004.896219
# min           0.000000     344.410000 -28153.110000
# 25%         157.432500    2466.702500    468.775000
# 50%         511.425000    5534.470000    992.940000
# 75%        1404.137500   14823.655000   2179.372500
# max       55299.710000  436824.650000  84315.090000

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_ID         0
# Customer_Name       0
# Gender              0
# Age                 0
# City                0
# State               0
# Region              0
# Product_ID          0
# Product_Name        0
# Category            0
# Sub_Category        0
# Unit_Price          0
# Quantity            0
# Discount_Percent    0
# Discount_Amount     0
# Sales               0
# Profit              0
# Payment_Method      0
# Order_Status        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_ID         0
# Customer_Name       0
# Gender              0
# Age                 0
# City                0
# State               0
# Region              0
# Product_ID          0
# Product_Name        0
# Category            0
# Sub_Category        0
# Unit_Price          0
# Quantity            0
# Discount_Percent    0
# Discount_Amount     0
# Sales               0
# Profit              0
# Payment_Method      0
# Order_Status        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
total_sales = df["Sales"].sum()
total_sales
# Out:
# np.float64(20513624.46)

# %%
total_profit = df["Profit"].sum()
total_profit
# Out:
# np.float64(2624932.9000000004)

# %%
total_orders = df["Order_ID"].nunique()
total_orders
# Out:
# 1000

# %%
total_quantity = df["Quantity"].sum()
total_quantity
# Out:
# np.int64(1931)

# %%
print("Total Sales:", df["Sales"].sum())
print("Total Profit:", df["Profit"].sum())
print("Total Orders:", df["Order_ID"].nunique())
print("Total Quantity:", df["Quantity"].sum())
# Out:
# Total Sales: 20513624.46
# Total Profit: 2624932.9000000004
# Total Orders: 1000
# Total Quantity: 1931

# %%
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)

region_sales
# Out:
# Region
# East     7599407.26
# West     6054130.60
# South    4077283.69
# North    2782802.91
# Name: Sales, dtype: float64

# %%
region_sales.plot(kind="bar")

plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")

plt.show()

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)

category_sales
# Out:
# Category
# Electronics       15014152.36
# Furniture          2194976.07
# Home & Kitchen     1515421.60
# Fashion             923963.76
# Sports              496071.11
# Beauty              257360.17
# Books               111679.39
# Name: Sales, dtype: float64

# %%
category_sales.plot(kind="bar")

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.show()

# %%
top_products = (
    df.groupby("Product_Name")["Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

top_products
# Out:
# Product_Name
# Laptop                 9607949.67
# Smartphone             4368830.26
# Study Table            1221173.72
# Office Chair            973802.35
# Air Fryer               961230.92
# Wireless Headphones     671623.94
# Running Shoes           584961.23
# Mixer Grinder           554190.68
# Power Bank              365748.49
# Dumbbell Set            336553.73
# Name: Sales, dtype: float64

# %%
top_products.plot(kind="barh")

plt.title("Top 10 Products by Sales")
plt.xlabel("Total Sales")
plt.ylabel("Product")

plt.show()

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])

# %%
df["Month"] = df["Order_Date"].dt.to_period("M")

# %%
monthly_sales = df.groupby("Month")["Sales"].sum()

monthly_sales
# Out:
# Month
# 2025-01     875604.70
# 2025-02     909445.64
# 2025-03     999519.76
# 2025-04     985458.88
# 2025-05     873725.04
# 2025-06     546109.93
# 2025-07    1374458.85
# 2025-08     674746.64
# 2025-09    1116608.55
# 2025-10     591275.11
# 2025-11    1847691.42
# 2025-12     839105.90
# 2026-01    1437400.43
# 2026-02    1079796.73
# 2026-03    1253430.21
# 2026-04     962090.98
# 2026-05     963241.94
# 2026-06    1179261.30
# 2026-07    1238944.55
# 2026-08     765707.90
# Freq: M, Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    monthly_sales.index.astype(str),
    monthly_sales.values,
    marker="o"
)

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
region_profit = (
    df.groupby("Region")["Profit"]
    .sum()
    .sort_values(ascending=False)
)

region_profit
# Out:
# Region
# East     883901.25
# West     834007.52
# South    528767.48
# North    378256.65
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(8, 5))

region_profit.plot(kind="bar")

plt.title("Profit by Region")
plt.xlabel("Region")
plt.ylabel("Total Profit")

plt.tight_layout()
plt.show()

# %%
payment_sales = (
    df.groupby("Payment_Method")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

payment_sales
# Out:
# Payment_Method
# Credit Card         4933952.88
# Debit Card          4204996.35
# Cash on Delivery    3943767.06
# UPI                 3921845.73
# Net Banking         3509062.44
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8, 5))

payment_sales.plot(kind="barh")

plt.title("Sales by Payment Method")
plt.xlabel("Total Sales")
plt.ylabel("Payment Method")

plt.tight_layout()
plt.show()

# %%
top_customers = (
    df.groupby("Customer_Name")["Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

top_customers
# Out:
# Customer_Name
# Aditi Joshi         631433.41
# Aditi Khan          506540.55
# Sneha Deshmukh      491663.92
# Siddharth Jadhav    413062.61
# Siddharth Gupta     394787.71
# Kunal Singh         367732.71
# Ananya Verma        350570.46
# Riya Reddy          342357.17
# Riya Singh          323074.05
# Aditya Mehta        322474.53
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10, 5))

top_customers.plot(kind="barh")

plt.title("Top 10 Customers by Sales")
plt.xlabel("Total Sales")
plt.ylabel("Customer Name")

plt.tight_layout()
plt.show()

# %%
status_sales = (
    df.groupby("Order_Status")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

status_sales
# Out:
# Order_Status
# Delivered    19436283.53
# Returned       617717.08
# Cancelled      459623.85
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8, 5))

status_sales.plot(kind="bar")

plt.title("Sales by Order Status")
plt.xlabel("Order Status")
plt.ylabel("Total Sales")

plt.tight_layout()
plt.show()

# %%
avg_discount = (
    df.groupby("Category")["Discount_Percent"]
    .mean()
    .sort_values(ascending=False)
)

avg_discount
# Out:
# Category
# Beauty            12.775000
# Fashion           11.990099
# Books             11.119403
# Sports             9.246032
# Electronics        8.802158
# Home & Kitchen     8.290323
# Furniture          7.723577
# Name: Discount_Percent, dtype: float64

# %%
profit_margin = (df["Profit"].sum() / df["Sales"].sum()) * 100

print("Profit Margin:", round(profit_margin, 2), "%")
# Out:
# Profit Margin: 12.8 %

# %%
status_sales = (
    df.groupby("Order_Status")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

status_sales
# Out:
# Order_Status
# Delivered    19436283.53
# Returned       617717.08
# Cancelled      459623.85
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8, 5))

status_sales.plot(kind="bar")

plt.title("Sales by Order Status")
plt.xlabel("Order Status")
plt.ylabel("Total Sales")

plt.tight_layout()
plt.show()

# %%
avg_discount = (
    df.groupby("Category")["Discount_Percent"]
    .mean()
    .sort_values(ascending=False)
)

avg_discount
# Out:
# Category
# Beauty            12.775000
# Fashion           11.990099
# Books             11.119403
# Sports             9.246032
# Electronics        8.802158
# Home & Kitchen     8.290323
# Furniture          7.723577
# Name: Discount_Percent, dtype: float64

# %%
profit_margin = (df["Profit"].sum() / df["Sales"].sum()) * 100

print("Profit Margin:", round(profit_margin, 2), "%")
# Out:
# Profit Margin: 12.8 %

# %%
profit_margin = (df["Profit"].sum() / df["Sales"].sum()) * 100

print("Profit Margin:", round(profit_margin, 2), "%")
# Out:
# Profit Margin: 12.8 %

# %%
print("Total Sales:", df["Sales"].sum())
print("Total Profit:", df["Profit"].sum())
print("Total Orders:", df["Order_ID"].nunique())
print("Total Quantity:", df["Quantity"].sum())
print("Profit Margin:", round(profit_margin, 2), "%")
# Out:
# Total Sales: 20513624.46
# Total Profit: 2624932.9000000004
# Total Orders: 1000
# Total Quantity: 1931
# Profit Margin: 12.8 %
